# %% [markdown]
# > **Frozen results snapshot — read-only proof of the reviewed capture.**
# >
# > This is a rendered record of a completed DRIFT Manual Run, not a runnable
# > notebook. The operator database host, provider/budget logs, and internal
# > review notes have been removed. To reproduce the review-first workflow, run
# > [`drift_manual_run.ipynb`](drift_manual_run.ipynb).

# %% [markdown]
# <style>
# .drift-hero { background: radial-gradient(circle at 18% 5%, #155e75, transparent 38%), linear-gradient(135deg,#07111f,#172554 58%,#3b0764); border-radius: 28px; color:#eef8ff; padding: 42px 46px; margin: 8px 0 28px; box-shadow: 0 22px 60px rgba(15,23,42,.28); }
# .drift-kicker { color:#67e8f9; font: 700 12px/1.2 system-ui; letter-spacing:.18em; text-transform:uppercase; }
# .drift-hero h1 { font: 800 52px/1.05 system-ui; letter-spacing:-.035em; margin:14px 0 14px; overflow-wrap:anywhere; }
# .drift-hero p { color:#cbd5e1; font: 18px/1.6 system-ui; max-width:720px; margin:0; }
# .drift-badges { margin-top:22px; display:flex; gap:8px; flex-wrap:wrap; }
# .drift-badge { border:1px solid rgba(103,232,249,.45); border-radius:999px; color:#cffafe; font:600 12px system-ui; padding:6px 10px; }
# .drift-grid { display:grid; grid-template-columns:repeat(4,minmax(0,1fr)); gap:12px; margin:18px 0 26px; }
# .drift-card { border:1px solid #dbeafe; border-radius:16px; background:#f8fbff; padding:16px; }
# .drift-card strong { display:block; color:#0f172a; font:700 14px system-ui; margin-bottom:6px; }
# .drift-card span { color:#475569; font:13px/1.45 system-ui; }
# .drift-panel { border:1px solid #bfdbfe; border-radius:18px; background:#f8fbff; padding:20px; margin:14px 0; }
# .drift-panel h3 { color:#0f172a; font:700 17px system-ui; margin:0 0 10px; }
# .drift-muted { color:#64748b; font:13px/1.5 system-ui; }
# .drift-ok { color:#047857; font:700 13px system-ui; }
# .drift-warn { color:#9a3412; font:700 13px system-ui; }
# .drift-table { width:100%; border-collapse:collapse; font:13px system-ui; }
# .drift-table th { color:#475569; font-size:11px; letter-spacing:.08em; text-align:left; text-transform:uppercase; padding:9px; border-bottom:1px solid #cbd5e1; }
# .drift-table td { color:#1e293b; padding:10px 9px; border-bottom:1px solid #e2e8f0; }
# .drift-claim { border-left:4px solid #38bdf8; border-radius:8px; background:#f8fafc; margin:10px 0; padding:12px 14px; }
# .drift-claim .kind { color:#0369a1; font:700 11px system-ui; letter-spacing:.08em; text-transform:uppercase; }
# .drift-claim .text { color:#0f172a; font:14px/1.5 system-ui; margin:4px 0 8px; }
# .drift-claim .quote { color:#475569; font:italic 13px/1.45 system-ui; }
# @media(max-width:800px){.drift-grid{grid-template-columns:1fr 1fr}.drift-hero{padding:30px}.drift-hero h1{font-size:40px}}
# </style>
#
# <section class="drift-hero">
#   <div class="drift-kicker">DRIFT · evidence run console</div>
#   <h1>DRIFT Manual Run</h1>
#   <p>Turn a bounded set of primary GPU and infrastructure releases into inspectable engineering evidence—then publish nothing until a human has reviewed every claim.</p>
#   <div class="drift-badges"><span class="drift-badge">Primary-source only</span><span class="drift-badge">Luna draft + verifier</span><span class="drift-badge">Human review gate</span><span class="drift-badge">SHA-256 evidence archive</span></div>
# </section>

# %% [markdown]
# <div class="drift-grid">
# <div class="drift-card"><strong>1 · Observe</strong><span>Read configured first-party release feeds. Source text remains data, never instructions.</span></div>
# <div class="drift-card"><strong>2 · Ground</strong><span>Freeze exact excerpts, offsets, hashes, and upstream PR/commit references for every claim.</span></div>
# <div class="drift-card"><strong>3 · Review</strong><span>Keep model output quarantined until a reviewer records meaningful notes.</span></div>
# <div class="drift-card"><strong>4 · Prove</strong><span>Write a scrubbed, immutable evidence record and SHA-256 manifest for the reviewed run.</span></div>
# </div>
#
# ### The judge-facing contract
#
# DRIFT promises traceable primary facts, explicitly labelled interpretation, and bounded checks. It does **not** claim compatibility certification, incident prediction, or that a model verifier proves a release claim.

# %% [markdown]
# ## 0. Preflight — prove the run is safe to start
#
# This cell checks mode, budget, API-key presence, and the effective database host without revealing a key, password, or full connection string. A public Railway TCP proxy may replace only the host/port of the private service URL.

# %%
import os
import sys
from html import escape
from pathlib import Path
from urllib.parse import urlsplit

from IPython.display import HTML, Markdown, display


def find_repository_root(start: Path) -> Path:
    for candidate in (start, *start.parents):
        if (candidate / 'backend' / 'sources.yaml').is_file():
            return candidate
    raise FileNotFoundError('Open this notebook from the DRIFT repository or a child directory.')


REPOSITORY_ROOT = find_repository_root(Path.cwd().resolve())
os.chdir(REPOSITORY_ROOT)
if str(REPOSITORY_ROOT) not in sys.path:
    sys.path.insert(0, str(REPOSITORY_ROOT))

from backend.core.config import settings

settings.validate()
database_host = urlsplit(settings.database_url).hostname or "unknown"
if settings.mode != "live":
    raise RuntimeError("Set DRIFT_MODE=live before a model-backed capture.")
if "postgres.railway.internal" in database_host:
    raise RuntimeError("The private Railway hostname is still active. Configure a public proxy override or local PostgreSQL.")

checks = [
    ("Live mode", settings.mode == "live", settings.mode),
    ("API key present", bool(settings.openai_api_key), "configured" if settings.openai_api_key else "missing"),
    ("Database route", bool(database_host), database_host),
    ("Project budget", True, f"${settings.max_spend_usd:.2f} cap · ${settings.max_call_usd:.2f} per-attempt reservation"),
]
rows = ''.join(f"<tr><td><span class='drift-ok'>● ready</span></td><td>{escape(label)}</td><td class='drift-muted'>{escape(detail)}</td></tr>" for label, ok, detail in checks if ok)
display(HTML(f"<section class='drift-panel'><h3>Run readiness</h3><table class='drift-table'><tbody>{rows}</tbody></table><p class='drift-muted'>No provider request has been made.</p></section>"))
print(f"Repository root: {REPOSITORY_ROOT}")
print(f"Spend ledger: {Path(settings.spend_ledger_path)}")
# Out:
# <section class='drift-panel'><h3>Run readiness</h3><table class='drift-table'><tbody><tr><td><span class='drift-ok'>● ready</span></td><td>Live mode</td><td class='drift-muted'>live</td></tr><tr><td><span class='drift-ok'>● ready</span></td><td>API key present</td><td class='drift-muted'>configured</td></tr><tr><td><span class='drift-ok'>● ready</span></td><td>Database route</td><td class='drift-muted'>[redacted-db-host]</td></tr><tr><td><span class='drift-ok'>● ready</span></td><td>Project budget</td><td class='drift-muted'>$5.00 cap · $0.25 per-attempt reservation</td></tr></tbody></table><p class='drift-muted'>No provider request has been made.</p></section>
# Repository root: C:\ws\drift
# Spend ledger: C:\ws\drift\.drift\spend-ledger.json

# %% [markdown]
# ## 1. Source roster — what this run will observe
#
# Every source is a configured primary GitHub release feed. This notebook starts with one recent item from each enabled source and caps the total at eight.

# %%
from backend.agents.scout import load_sources

sources = [source for source in load_sources() if source.get("enabled", True)]
source_rows = ''.join(
    f"<tr><td><strong>{escape(source['id'])}</strong></td><td>{escape(source['name'])}</td><td>{escape(source['category'])}</td><td><a href='{escape(source['feed_url'], quote=True)}' target='_blank'>primary feed ↗</a></td></tr>"
    for source in sources
)
display(HTML(f"<section class='drift-panel'><h3>{len(sources)} primary sources ready</h3><table class='drift-table'><thead><tr><th>ID</th><th>Project</th><th>Category</th><th>Evidence</th></tr></thead><tbody>{source_rows}</tbody></table></section>"))
# Out:
# <section class='drift-panel'><h3>8 primary sources ready</h3><table class='drift-table'><thead><tr><th>ID</th><th>Project</th><th>Category</th><th>Evidence</th></tr></thead><tbody><tr><td><strong>pytorch</strong></td><td>PyTorch</td><td>framework</td><td><a href='https://github.com/pytorch/pytorch/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>tensorrt</strong></td><td>NVIDIA TensorRT</td><td>inference</td><td><a href='https://github.com/NVIDIA/TensorRT/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>triton</strong></td><td>Triton</td><td>compiler</td><td><a href='https://github.com/triton-lang/triton/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>vllm</strong></td><td>vLLM</td><td>inference</td><td><a href='https://github.com/vllm-project/vllm/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>transformers</strong></td><td>Hugging Face Transformers</td><td>framework</td><td><a href='https://github.com/huggingface/transformers/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>cutlass</strong></td><td>NVIDIA CUTLASS</td><td>kernels</td><td><a href='https://github.com/NVIDIA/cutlass/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>jax</strong></td><td>JAX</td><td>framework</td><td><a href='https://github.com/google/jax/releases.atom' target='_blank'>primary feed ↗</a></td></tr><tr><td><strong>nccl</strong></td><td>NVIDIA NCCL</td><td>distributed</td><td><a href='https://github.com/NVIDIA/nccl/releases.atom' target='_blank'>primary feed ↗</a></td></tr></tbody></table></section>

# %% [markdown]
# ## 2. Configure the bounded run
#
# Luna drafts and separately verifies claims. Depending on clustering, this all-source run may make up to **24 structured model calls** (classification, draft, verifier for each source) and two embedding calls. The spend guard reserves a retry envelope and settles reported usage; it blocks the project ceiling.
#
# Set `CONFIRM_CAPTURE = "RUN"` only after you accept the provider spend.

# %%
from datetime import UTC, datetime

from backend.core.model_router import Tier

SOURCE_IDS = {source['id'] for source in sources}
PER_SOURCE_LIMIT = 1
MAX_ITEMS = 8
TIER = Tier.DEV
RUN_LABEL = f"{datetime.now(UTC).date().isoformat()}-all-sources-reviewed"
CONFIRM_CAPTURE = ""  # Set to "RUN" only after you accept the provider spend.

if not SOURCE_IDS or PER_SOURCE_LIMIT < 1 or MAX_ITEMS < 1:
    raise ValueError("Choose at least one source and positive limits.")
max_structured_calls = len(SOURCE_IDS) * 3
display(HTML(f"<section class='drift-panel'><h3>Bounded all-source plan</h3><p class='drift-muted'>Sources: <strong>{', '.join(sorted(SOURCE_IDS))}</strong><br>Selection: <strong>{PER_SOURCE_LIMIT} per source · {MAX_ITEMS} total</strong><br>Model tier: <strong>{TIER.value} / Luna</strong><br>Potential provider operations: <strong>up to {max_structured_calls} structured + 2 embedding calls</strong><br>Evidence archive name: <strong>{RUN_LABEL}</strong></p><p class='drift-warn'>Capture confirmation: {escape(CONFIRM_CAPTURE or 'not set')} — no provider call until this equals RUN.</p></section>"))
# Out:
# <section class='drift-panel'><h3>Bounded all-source plan</h3><p class='drift-muted'>Sources: <strong>cutlass, jax, nccl, pytorch, tensorrt, transformers, triton, vllm</strong><br>Selection: <strong>1 per source · 8 total</strong><br>Model tier: <strong>dev / Luna</strong><br>Potential provider operations: <strong>up to 24 structured + 2 embedding calls</strong><br>Evidence archive name: <strong>2026-07-16-all-sources-reviewed</strong></p><p class='drift-warn'>Capture confirmation: RUN — no provider call until this equals RUN.</p></section>

# %% [markdown]
# ## 3. Capture — drafts only
#
# This runs Scout → Synthesizer → claim extraction → separate verifier. Successful records remain private drafts; nothing appears in live briefing, search, or chat yet.

# %%
from backend.pipeline import run_capture

if CONFIRM_CAPTURE != "RUN":
    display(HTML("<section class='drift-panel'><h3>Capture paused</h3><p class='drift-warn'>Set CONFIRM_CAPTURE = 'RUN' in the previous cell, re-run it, then run this cell.</p></section>"))
else:
    capture = await run_capture(
        source_ids=SOURCE_IDS,
        per_source_limit=PER_SOURCE_LIMIT,
        max_items=MAX_ITEMS,
        tier=TIER,
    )
    display(HTML(f"<section class='drift-panel'><h3>Draft capture complete</h3><p class='drift-ok'>Fetched {capture.fetched_count} · selected {capture.selected_count} · persisted raw evidence {capture.persisted_raw_count} · draft Insight IDs {capture.insight_ids}</p><p class='drift-muted'>These records are quarantined until the review step below.</p></section>"))
# Out:
# Provider and budget logs removed from this rendered snapshot. The bounded run settled at $0.2408795 total across 8 sources; 6 verifier-passed drafts, 4 reviewed and published.
# <section class='drift-panel'><h3>Draft capture complete</h3><p class='drift-ok'>Fetched 80 · selected 8 · persisted raw evidence 0 · draft Insight IDs [3, 4, 5, 6, 7, 8]</p><p class='drift-muted'>These records are quarantined until the review step below.</p></section>

# %% [markdown]
# ## 4. Inspect — make every claim earn trust
#
# Read the exact source excerpts. Direct facts, conditional interpretations, and recommended checks must remain visibly distinct. The verifier is screening—not proof.

# %%
from sqlalchemy import select

from backend.models.schema import InsightRow, session_factory

if 'capture' not in globals():
    display(HTML("<section class='drift-panel'><h3>Nothing to inspect yet</h3><p class='drift-muted'>Complete the draft capture first.</p></section>"))
else:
    async with session_factory() as session:
        draft_rows = (await session.scalars(select(InsightRow).where(InsightRow.id.in_(capture.insight_ids)))).all()
    for row in draft_rows:
        claims = ''.join(
            f"<article class='drift-claim'><div class='kind'>{escape(claim['kind'])}</div><div class='text'>{escape(claim['text'])}</div>" + ''.join(
                f"<div class='quote'>“{escape(evidence['excerpt'])}”<br><a href='{escape(evidence['source_url'], quote=True)}' target='_blank'>open primary source ↗</a> · chars {evidence['start_char']}–{evidence['end_char']}</div>"
                for evidence in claim['evidence']
            ) + "</article>"
            for claim in row.claims
        )
        risks = ', '.join(row.operator_risks) or 'none labelled'
        display(HTML(f"<section class='drift-panel'><h3>Draft {row.id} · {escape(row.title)}</h3><p class='drift-muted'>Verifier: <strong>{escape(row.verification_status)}</strong> · upstream release type: <strong>{escape(row.upstream_release_type)}</strong> · potential operator risks: <strong>{escape(risks)}</strong></p>{claims}</section>"))
# Out:
# <section class='drift-panel'><h3>Draft 3 · Patch release: v5.14.1</h3><p class='drift-muted'>Verifier: <strong>passed</strong> · upstream release type: <strong>patch</strong> · potential operator risks: <strong>compatibility, correctness, performance, reliability, startup</strong></p><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>Transformers v5.14.1 is a patch release that addresses issues encountered while integrating the Inkling model, including an issue affecting models using EncoderDecoderCache during assisted generation.</div><div class='quote'>“Patch release v5.14.1”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 4–25</div><div class='quote'>“This patch solves a few issues which appeared when integrating Inkling model, most notably an issue affecting models using EncoderDecoderCache during assisted generation.”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 34–204</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>The release fixes an issue involving prefill with StaticCache and SDPA without padding for Inkling models using position_bias.</div><div class='quote'>“It also fixes an issue that could appear during prefill with StaticCache and sdpa without padding for Inkling which uses a position_bias.”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 205–342</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>The release includes fixes for assisted decoding with EncoderDecoder cache and OlmoHybrid, SDPA prefill with position_bias, DeepGEMM on multiple devices, and an FP8 kernels version bump.</div><div class='quote'>“Fix sdpa prefill with position_bias”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 397–432</div><div class='quote'>“Fix assisted decoding for models with EncoderDecoder cache &amp;amp; OlmoHybrid”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 647–722</div><div class='quote'>“[FP8] Bump kernels version”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 937–963</div><div class='quote'>“Fix deepgemm on multiple devices”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 1166–1198</div></article><article class='drift-claim'><div class='kind'>inference</div><div class='text'>Deployments using Inkling, assisted generation, StaticCache prefill, SDPA without padding, FP8 kernels, or DeepGEMM across multiple devices may exercise the areas changed by this release; the operational impact should be validated in representative GPU inference workloads.</div><div class='quote'>“This patch solves a few issues which appeared when integrating Inkling model, most notably an issue affecting models using EncoderDecoderCache during assisted generation. It also fixes an issue that could appear during prefill with StaticCache and sdpa without padding for Inkling which uses a position_bias.”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 34–342</div><div class='quote'>“[FP8] Bump kernels version”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 937–963</div><div class='quote'>“Fix deepgemm on multiple devices”<br><a href='https://github.com/huggingface/transformers/releases/tag/v5.14.1' target='_blank'>open primary source ↗</a> · chars 1166–1198</div></article><article class='drift-claim'><div class='kind ...
# <section class='drift-panel'><h3>Draft 4 · trunk/44520d260bddd66db06c89485f8567a840bbf7e6: flex_gemm: support compressed local reduce aux outputs (#188469)</h3><p class='drift-muted'>Verifier: <strong>passed</strong> · upstream release type: <strong>unknown</strong> · potential operator risks: <strong>compatibility, correctness, performance, startup</strong></p><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>FlexGEMM adds support for local reductions in GEMM epilogues, including compressed auxiliary outputs such as the returned `scale` tensor.</div><div class='quote'>“The last example is both feed-main and a compressed aux store because it returns &lt;code&gt;scale&lt;/code&gt;. A feed-only version just returns &lt;code&gt;out&lt;/code&gt;.”<br><a href='https://github.com/pytorch/pytorch/releases/tag/trunk%2F44520d260bddd66db06c89485f8567a840bbf7e6' target='_blank'>open primary source ↗</a> · chars 3497–3648</div><div class='quote'>“At a high level we are trying to add reductions in the epilogue.”<br><a href='https://github.com/pytorch/pytorch/releases/tag/trunk%2F44520d260bddd66db06c89485f8567a840bbf7e6' target='_blank'>open primary source ↗</a> · chars 196–260</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>The supported local-reduction forms reduce along either the M dimension or the N dimension, and the reduction group must fit within the selected CTA tile, be compatible with that tile, and divide the logical M or N dimension.</div><div class='quote'>“Since we are still only dealing with 2-D M/N tiles, we basically have two different forms of local reductions: along the M dimension or along the N dimension. To be local, the group must fit inside the selected CTA tile and the tile must be compatible with that group. The group also has to divide the logical M or N dimension.”<br><a href='https://github.com/pytorch/pytorch/releases/tag/trunk%2F44520d260bddd66db06c89485f8567a840bbf7e6' target='_blank'>open primary source ↗</a> · chars 3656–3983</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>Groups up to 32 must divide the 32-wide TensorSSA fragment; larger groups must be multiples of 32.</div><div class='quote'>“Groups up to 32 must divide the 32-wide TensorSSA fragment; larger groups must be multiples of 32.”<br><a href='https://github.com/pytorch/pytorch/releases/tag/trunk%2F44520d260bddd66db06c89485f8567a840bbf7e6' target='_blank'>open primary source ↗</a> · chars 3984–4082</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>N-axis groups up to one 32-wide TensorSSA fragment use in-fragment TensorSSA reductions, while larger N-axis groups produce TensorSSA partials that QuACK combines physically.</div><div class='quote'>“N-axis groups up to one 32-wide TensorSSA fragment lower as ordinary in-fragment TensorSSA reductions; larger N groups produce TensorSSA partials that QuACK combines physically.”<br><a href='https://github.com/pytorch/pytorch/releases/tag/trunk%2F44520d260bddd66db06c89485f8567a840bbf7e6' target='_blank'>open primary source ↗</a> · chars 4363–4540</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>M-axis groups use QuACK&#x27;s physical lane/warp combine path, and reductions spanning M warps may require shared memory.</div><div class='quote'>“M-axis groups currently always use QuACK&#x27;s physical lane/warp combine path, even when the group is small enough to fit in one fragment.”<br><a href='https://github.com/pytorch/pytorch/releases/tag/trunk%2F44520d260bddd66db06c89485f8567a840bbf7e6' target='_blank'>open primary source ↗</a> · chars 4548–4683</div><div class='quote'>“Operationally we still get the distinction we care about here: fragment-sized N reductions can stay in TensorSSA, while M reductions require lane/warp reduction and may require shared memory when they span M warps.”<br> ...
# <section class='drift-panel'><h3>Draft 5 · CUTLASS 4.6.1</h3><p class='drift-muted'>Verifier: <strong>passed</strong> · upstream release type: <strong>unknown</strong> · potential operator risks: <strong>compatibility, correctness, startup</strong></p><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>CUTLASS 4.6.1 reports fixes for a compilation failure on Thor when using the 12.9 wheel.</div><div class='quote'>“Fixed a compilation failure on Thor with 12.9 wheel”<br><a href='https://github.com/NVIDIA/cutlass/releases/tag/v4.6.1' target='_blank'>open primary source ↗</a> · chars 541–592</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>CUTLASS 4.6.1 reports fixing a regression of FlashAttention v2 on Ampere.</div><div class='quote'>“Fixed a per regression of flash attention v2 on Ampere”<br><a href='https://github.com/NVIDIA/cutlass/releases/tag/v4.6.1' target='_blank'>open primary source ↗</a> · chars 602–656</div></article><article class='drift-claim'><div class='kind'>inference</div><div class='text'>Deployments using the Thor platform with the CUDA 12.9 wheel may no longer encounter the reported compilation failure, but compilation should be validated in the target build environment.</div><div class='quote'>“Fixed a compilation failure on Thor with 12.9 wheel”<br><a href='https://github.com/NVIDIA/cutlass/releases/tag/v4.6.1' target='_blank'>open primary source ↗</a> · chars 541–592</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>Run a representative FlashAttention v2 test on Ampere GPUs after upgrading, and compare compilation and correctness results with the prior version.</div><div class='quote'>“Fixed a per regression of flash attention v2 on Ampere”<br><a href='https://github.com/NVIDIA/cutlass/releases/tag/v4.6.1' target='_blank'>open primary source ↗</a> · chars 602–656</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>Test existing JAX integrations that register custom or multiple FFI calls, including registration and invocation paths.</div><div class='quote'>“Allow custom and multiple FFI call registration for Jax”<br><a href='https://github.com/NVIDIA/cutlass/releases/tag/v4.6.1' target='_blank'>open primary source ↗</a> · chars 666–721</div></article></section>
# <section class='drift-panel'><h3>Draft 6 · v0.25.1</h3><p class='drift-muted'>Verifier: <strong>passed</strong> · upstream release type: <strong>patch</strong> · potential operator risks: <strong>compatibility, correctness, startup, reliability</strong></p><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>vLLM v0.25.1 is a patch release containing two targeted bug fixes on top of v0.25.0.</div><div class='quote'>“v0.25.1 is a patch release containing two targeted bug fixes on top of v0.25.0.”<br><a href='https://github.com/vllm-project/vllm/releases/tag/v0.25.1' target='_blank'>open primary source ↗</a> · chars 113–192</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>When system FFmpeg is unavailable, importing TorchCodec no longer blocks model startup; the error is deferred until runtime and surfaces only if TorchCodec is needed.</div><div class='quote'>“Previously &lt;code&gt;import torchcodec&lt;/code&gt; raised a &lt;code&gt;RuntimeError&lt;/code&gt; at import time when system FFmpeg was missing, which blocked startup (e.g. &lt;code&gt;vllm serve Qwen/Qwen3-VL-2B-Instruct&lt;/code&gt;) even when TorchCodec was not in use. The error is now deferred to runtime so it only surfaces if TorchCodec is actually needed.”<br><a href='https://github.com/vllm-project/vllm/releases/tag/v0.25.1' target='_blank'>open primary source ↗</a> · chars 428–758</div></article><article class='drift-claim'><div class='kind'>inference</div><div class='text'>If a deployment uses TorchCodec-dependent functionality without system FFmpeg, operators may encounter the deferred FFmpeg-related error at runtime rather than during model launch.</div><div class='quote'>“The error is now deferred to runtime so it only surfaces if TorchCodec is actually needed.”<br><a href='https://github.com/vllm-project/vllm/releases/tag/v0.25.1' target='_blank'>open primary source ↗</a> · chars 668–758</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>If serving models that use NVFP4 or other mixed-dtype RMSNorm paths, validate generated output after upgrading, because the release identifies prior mixed-dtype fusion as capable of corrupting hidden state and producing garbage output.</div><div class='quote'>“The fused FlashInfer allreduce + RMSNorm + static-quantization patterns could match graphs where the activation and RMSNorm weight dtypes differ (e.g. a BF16 residual stream with an FP32 Gemma/Qwen-style RMSNorm weight in NVFP4 models), corrupting the hidden state and producing garbage output such as repeated &lt;code&gt;!!!!!&lt;/code&gt; tokens.”<br><a href='https://github.com/vllm-project/vllm/releases/tag/v0.25.1' target='_blank'>open primary source ↗</a> · chars 940–1277</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>For deployments that do not use TorchCodec, verify that model startup succeeds without system FFmpeg and separately exercise a TorchCodec-dependent request to confirm the expected runtime failure behavior when FFmpeg is absent.</div><div class='quote'>“Previously &lt;code&gt;import torchcodec&lt;/code&gt; raised a &lt;code&gt;RuntimeError&lt;/code&gt; at import time when system FFmpeg was missing, which blocked startup (e.g. &lt;code&gt;vllm serve Qwen/Qwen3-VL-2B-Instruct&lt;/code&gt;) even when TorchCodec was not in use. The error is now deferred to runtime so it only surfaces if TorchCodec is actually needed.”<br><a href='https://github.com/vllm-project/vllm/releases/tag/v0.25.1' target='_blank'>open primary source ↗</a> · chars 428–758</div></article></section>
# <section class='drift-panel'><h3>Draft 7 · NCCL v2.30.7-1 Release</h3><p class='drift-muted'>Verifier: <strong>passed</strong> · upstream release type: <strong>unknown</strong> · potential operator risks: <strong>compatibility, correctness, performance, reliability, startup</strong></p><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>NCCL v2.30.7-1 adds hierarchical zero-SM AllGather and All2all collectives using an RMA CPU proxy for inter-node communication and Copy Engines for intra-node communication.</div><div class='quote'>“Adds hierarchical zero-SM collectives (AllGather and All2all) that use RMA CPU proxy for inter-node communication and Copy Engines for intra-node communication.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 38–198</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>Hierarchical zero-SM collectives are enabled with the NCCL_CTA_POLICY_ZERO flag.</div><div class='quote'>“Enable hierarchical zero-SM collectives with &lt;code&gt;NCCL_CTA_POLICY_ZERO&lt;/code&gt; flag.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 270–354</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>NCCL adds an experimental GPU Push Interface (GPI) backend for GIN and drops support for v11 and v12 GIN plugin APIs.</div><div class='quote'>“Adds new experimental GPU Push Interface (GPI) backend for GIN.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 401–464</div><div class='quote'>“Drops support for v11 and v12 GIN plugin APIs.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 2951–2997</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>NCCL adds support for window registration during CUDA graph capture and for asymmetric buffer sizes during window registration.</div><div class='quote'>“Adds support for asymmetric buffer sizes during window registration.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 1113–1181</div><div class='quote'>“Adds support for window registration during CUDA graph capture.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 1402–1465</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>NCCL supports up to two ranks per physical GPU with MPS plus MLOPart, and this support is marked experimental.</div><div class='quote'>“&lt;h2&gt;MPS with MLOPart Support (Experimental)&lt;/h2&gt;”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 1477–1525</div><div class='quote'>“Supports up to 2 ranks per physical GPU with MPS+mlopart.”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 1623–1680</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>The release adds the NCCL_RMA_DISABLE environment variable to enable or disable RMA.</div><div class='quote'>“Adds &lt;code&gt;NCCL_RMA_DISABLE&lt;/code&gt; env to enable/disable RMA (Github PR &lt;a class=&quot;issue-link js-issue-link&quot; href=&quot;https://github.com/NVIDIA/nccl/pull/2151&quot;&gt;#2151&lt;/a&gt;).”<br><a href='https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1' target='_blank'>open primary source ↗</a> · chars 1958–2125</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>The release notes identify a known issue requiring every rank to call one-sided host RMA APIs, such as ncclPutSignal, for a one-time initialization w ...
# <section class='drift-panel'><h3>Draft 8 · TensorRT 11.1 Release</h3><p class='drift-muted'>Verifier: <strong>passed</strong> · upstream release type: <strong>unknown</strong> · potential operator risks: <strong>compatibility, correctness, performance, startup</strong></p><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>TensorRT 11.1 updates the default CUDA version to 13.3.</div><div class='quote'>“Default CUDA version updated to 13.3.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 218–255</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>TensorRT 11.1 adds an Ubuntu 26.04 container.</div><div class='quote'>“Added Ubuntu 26.04 container.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 265–294</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>TensorRT 11.1 adds support for Python 3.14.</div><div class='quote'>“Added support for Python 3.14.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 304–334</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>TensorRT 11.1 adds a global performance tuner option in trtexec.</div><div class='quote'>“Added a global performance tuner option in trtexec.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 475–526</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>TensorRT 11.1 adds the topkLastDimPlugin plugin.</div><div class='quote'>“Added new plugin topkLastDimPlugin.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 564–599</div></article><article class='drift-claim'><div class='kind'>direct_fact</div><div class='text'>TensorRT 11.1 updates TRT_Attention to support raggedness.</div><div class='quote'>“Updated TRT_Attention to support raggedness.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 637–681</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>If the deployment uses TensorRT&#x27;s default CUDA configuration, verify that the host, container, driver, and dependent libraries support CUDA 13.3 before rollout.</div><div class='quote'>“Default CUDA version updated to 13.3.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 218–255</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>If Python is part of the deployment environment, test the application&#x27;s TensorRT integration under Python 3.14, including package installation and representative inference workflows.</div><div class='quote'>“Added support for Python 3.14.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 304–334</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>If operators adopt the new trtexec global performance tuner option, benchmark representative workloads and compare latency, throughput, and resource usage against the existing configuration.</div><div class='quote'>“Added a global performance tuner option in trtexec.”<br><a href='https://github.com/NVIDIA/TensorRT/releases/tag/v11.1' target='_blank'>open primary source ↗</a> · chars 475–526</div></article><article class='drift-claim'><div class='kind'>recommended_check</div><div class='text'>If models use TRT_Attention with ragged inputs, validate parsing, engine building, and numerical results for representative raggedness patterns.</div><div class='quote'>“Up ...

# %% [markdown]
# ## 5. Human review — the publication gate
#
# Enter only draft IDs you personally checked against the source excerpts. Notes must state what was reviewed. This is the only step that makes a record eligible for live `/briefing`, `/search`, and `/chat`.

# %%
from backend.review import publish_verified_insights

PUBLISH_IDS: list[int] = [3, 6, 7, 8]  # reviewed IDs from the recorded run
REVIEW_NOTES = "[redacted - recorded privately; not part of the public evidence record]"

if PUBLISH_IDS:
    async with session_factory() as session:
        published = await publish_verified_insights(session, PUBLISH_IDS, review_notes=REVIEW_NOTES)
    display(HTML(f"<section class='drift-panel'><h3>Published after human review</h3><p class='drift-ok'>Reviewed Insight IDs: {published}</p></section>"))
else:
    display(HTML("<section class='drift-panel'><h3>Review gate closed</h3><p class='drift-warn'>No record is public. Add personally reviewed IDs and meaningful notes only when ready.</p></section>"))
# Out:
# <section class='drift-panel'><h3>Published after human review</h3><p class='drift-ok'>Reviewed Insight IDs: [3, 6, 7, 8]</p></section>

# %% [markdown]
# ## 6. Evidence archive — leave a reproducible proof
#
# Archive only published IDs from this run. The output contains public Insight fields, typed claims, frozen excerpts, and capture counts—but never review notes, keys, connection strings, or spend-ledger contents. A SHA-256 manifest prevents silent replacement.

# %%
from backend.core.live_store import _row_to_insight
from backend.evidence_archive import archive_reviewed_capture

ARCHIVE_IDS: list[int] = [3, 6, 7, 8]  # reviewed IDs only, e.g. [12, 13]
ARCHIVE_NAME = RUN_LABEL

if ARCHIVE_IDS:
    if 'capture' not in globals():
        raise RuntimeError("Archive only evidence created by a completed notebook capture.")
    async with session_factory() as session:
        archive_rows = (await session.scalars(select(InsightRow).where(InsightRow.id.in_(ARCHIVE_IDS)))).all()
    if {row.id for row in archive_rows} != set(ARCHIVE_IDS):
        raise ValueError("Every ARCHIVE_ID must exist before evidence is written.")
    archive = archive_reviewed_capture(
        [_row_to_insight(row) for row in archive_rows],
        archive_name=ARCHIVE_NAME,
        capture_metadata={
            'source_ids': sorted(SOURCE_IDS),
            'fetched_count': capture.fetched_count,
            'selected_count': capture.selected_count,
            'persisted_raw_count': capture.persisted_raw_count,
            'draft_insight_ids': capture.insight_ids,
        },
    )
    display(HTML(f"<section class='drift-panel'><h3>Evidence archived</h3><p class='drift-ok'>JSON: {escape(str(archive.evidence_path))}<br>Manifest: {escape(str(archive.manifest_path))}<br>SHA-256: <code>{archive.sha256}</code></p></section>"))
else:
    display(HTML("<section class='drift-panel'><h3>Archive waiting for review</h3><p class='drift-warn'>No file written. Archive only reviewed, published IDs.</p></section>"))
# Out:
# <section class='drift-panel'><h3>Evidence archived</h3><p class='drift-ok'>JSON: assets\evidence\2026-07-16-all-sources-reviewed.json<br>Manifest: assets\evidence\2026-07-16-all-sources-reviewed.manifest.json<br>SHA-256: <code>2e08896b3c1c9507b557fc84e5558ce05343f9202227bb3a1ff7e964002d2318</code></p></section>

# %% [markdown]
# ---
#
# ### What a completed DRIFT Manual Run proves
#
# - The selected primary releases were captured within explicit limits.
# - Every public claim is traceable to a frozen primary-source excerpt.
# - Model reasoning is labelled and separately screened.
# - A human—not the model—approved publication.
# - The reviewed result is saved as a dated, checksummed evidence artifact.
#
# That is useful release intelligence without pretending to be a compatibility guarantee.
