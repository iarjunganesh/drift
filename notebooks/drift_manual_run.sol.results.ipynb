# %% [markdown]
# # DRIFT reviewed-capture results (Tier.FINAL / Sol) — 2026-07-17
#
# This is a frozen, display-only record of the completed bounded **Tier.FINAL** capture, drafted and verified at `gpt-5.6-sol`. It deliberately contains **no executable cells**, environment/configuration values, database endpoint, provider-budget log, or human review notes.
#
# It is a companion to the earlier `gpt-5.6-luna` reviewed run recorded in [`drift_manual_run.luna.results.ipynb`](drift_manual_run.luna.results.ipynb), not a replacement for it.
#
# For the durable claim evidence and integrity manifest, use [`assets/evidence/2026-07-17-all-sources-sol.json`](../assets/evidence/2026-07-17-all-sources-sol.json) and its companion manifest.

# %% [markdown]
# ## Recorded outcome
#
# - Eight configured primary-release sources were sampled (one selected item per source).
# - Eight clusters produced verifier-passed drafts (IDs 9–16), each drafted and separately verified at `gpt-5.6-sol`.
# - Five Insights were human-reviewed and published: IDs **10, 11, 13, 15, and 16**.
# - Three verifier-passed drafts were held after human review and left unpublished: **9** (a single PyTorch trunk commit rather than a release), **12** (CUTLASS 4.6.1, thin evidence with an interpretive expansion of an upstream typo), and **14** (an out-of-tree Triton `gfx950` tutorial pin rather than a mainline release).
# - This is a small, bounded reviewed set—not continuous or comprehensive release monitoring.

# %% [markdown]
# ## Published reviewed Insights
#
# | ID | Release | Primary source |
# | --- | --- | --- |
# | 10 | JAX v0.11.0 | [GitHub release](https://github.com/jax-ml/jax/releases/tag/jax-v0.11.0) |
# | 11 | Transformers v5.14.1 | [GitHub release](https://github.com/huggingface/transformers/releases/tag/v5.14.1) |
# | 13 | vLLM v0.25.1 | [GitHub release](https://github.com/vllm-project/vllm/releases/tag/v0.25.1) |
# | 15 | NCCL v2.30.7-1 | [GitHub release](https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1) |
# | 16 | TensorRT 11.1 | [GitHub release](https://github.com/NVIDIA/TensorRT/releases/tag/v11.1) |
#
# The archive preserves typed claims, exact frozen source spans, offsets, source-content hashes, citations, confidence, and bounded checks. It intentionally excludes private human-review rationale.

# %% [markdown]
# ## Integrity and operating boundary
#
# The evidence manifest records SHA-256 `df32b3d4315b09fb4a6dbd508d381ca2c8095e25e16f88c4741ce7bc3055a337`; it is computed over the archive's exact UTF-8 LF bytes.
#
# To make a future capture, start from the clean [`drift_manual_run.ipynb`](drift_manual_run.ipynb) template, review drafts manually, and create a new dated archive. Do not reuse this results record as an operator notebook.
