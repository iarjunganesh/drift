# %% [markdown]
# # DRIFT reviewed-capture results — 2026-07-16
#
# This is a frozen, display-only record of the completed bounded capture. It deliberately contains **no executable cells**, environment/configuration values, database endpoint, provider-budget log, or human review notes.
#
# For the durable claim evidence and integrity manifest, use [`assets/evidence/2026-07-16-all-sources-luna.json`](../assets/evidence/2026-07-16-all-sources-luna.json) and its companion manifest.

# %% [markdown]
# ## Recorded outcome
#
# - Eight configured primary-release sources were sampled (one selected item per source).
# - Six clusters produced verifier-passed drafts.
# - Four Insights were human-reviewed and published: IDs **3, 6, 7, and 8**.
# - This is a small, bounded reviewed set—not continuous or comprehensive release monitoring.

# %% [markdown]
# ## Published reviewed Insights
#
# | ID | Release | Primary source |
# | --- | --- | --- |
# | 3 | Transformers v5.14.1 | [GitHub release](https://github.com/huggingface/transformers/releases/tag/v5.14.1) |
# | 6 | vLLM v0.25.1 | [GitHub release](https://github.com/vllm-project/vllm/releases/tag/v0.25.1) |
# | 7 | NCCL v2.30.7-1 | [GitHub release](https://github.com/NVIDIA/nccl/releases/tag/v2.30.7-1) |
# | 8 | TensorRT 11.1 | [GitHub release](https://github.com/NVIDIA/TensorRT/releases/tag/v11.1) |
#
# The archive preserves typed claims, exact frozen source spans, offsets, source-content hashes, citations, confidence, and bounded checks. It intentionally excludes private human-review rationale.

# %% [markdown]
# ## Integrity and operating boundary
#
# The evidence manifest records SHA-256 `2e08896b3c1c9507b557fc84e5558ce05343f9202227bb3a1ff7e964002d2318`; it is computed over the archive's exact UTF-8 LF bytes.
#
# To make a future capture, start from the clean [`drift_manual_run.ipynb`](drift_manual_run.ipynb) template, review drafts manually, and create a new dated archive. Do not reuse this results record as an operator notebook.
